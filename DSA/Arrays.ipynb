# %%
stock_prices = [298, 305, 320, 301, 292]
print(stock_prices[0]) # prices on day 1
print(stock_prices[1]) # prices on day 2
# Out:
# 298
# 305

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Pointers pointing to memory locations

# %%
# what was the price on day 3?
stock_prices[2]
# Out:
# 320

# %% [markdown]
# Exercise: Array DataStructure
#
# Let us say your expense for every month are listed below,
#
# - January - 2200
# - February - 2350
# - March - 2600
# - April - 2130
# - May - 2190
#
# Create a list to store these monthly expenses and using that find out,
# 1. In Feb, how many dollars you spent extra compare to January?
# 2. Find out your total expense in first quarter (first three months) of the year.
# 3. Find out if you spent exactly 2000 dollars in any month
# 4. June month just finished and your expense is 1980 dollar. Add this item to our monthly expense list
# 5. You returned an item that you bought in a month of April and
# got a refund of 200$. Make a correction to your monthly expense list
# based on this

# %%
expenses = [2200, 2350, 2600, 2130, 2190]

# 1
print(expenses[1] - expenses[0], "is the amount spent extra in February compared to January")

# 2
q1_sum = 0
for i in expenses[:3]:
    q1_sum = q1_sum + i
print("The total expenses in first quarter is:", q1_sum)

# 3
for i in expenses:
    if i == 2000:
        print("There is(are) month(s) where I spent exactly 2000 dollars")

# # 4
expenses.append(1980)
print(f"The monthly expenses are: {expenses}")

# 5
expenses[3] = expenses[3] - 200
print(f"The updated expenses for April is {expenses[3]}")
# Out:
# 150 is the amount spent extra in February compared to January
# The total expenses in first quarter is: 7150
# The monthly expenses are: [2200, 2350, 2600, 2130, 2190, 1980]
# The updated expenses for April is 1930

# %% [markdown]
# You have a list of your favourite marvel super heros.
#
# 1. Length of the list
# 2. Add 'black panther' at the end of this list
# 3. You realize that you need to add 'black panther' after 'hulk',
#    so remove it from the list first and then add it after 'hulk'
# 4. Now you don't like thor and hulk because they get angry easily :)
#    So you want to remove thor and hulk from list and replace them with doctor strange (because he is cool).
#    Do that with one line of code.
# 5. Sort the heros list in alphabetical order (Hint. Use dir() functions to list down all functions available in list)

# %%
heros=['spider man','thor','hulk','iron man','captain america']

# 1
print(len(heros))

# 2
heros.append('black panther')
print(heros)

#3
if 'black panther' in heros:
    heros.remove('black panther') 
index_hulk = heros.index('hulk')
heros.insert(index_hulk + 1, 'black panther')

print(heros)

#4
heros = ['doctor strange' if hero == 'hulk' or hero == 'thor' else hero for hero in heros]
print(heros)

#5: buble sort
n = len(heros)
for i in range(n):
    for j in range(0, n - i - 1):
        if heros[j] > heros[j + 1]:
            heros[j], heros[j + 1] = heros[j + 1], heros[j]
print(heros)
# Out:
# 5
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america', 'black panther']
# ['spider man', 'thor', 'hulk', 'black panther', 'iron man', 'captain america']
# ['spider man', 'doctor strange', 'doctor strange', 'black panther', 'iron man', 'captain america']
# ['black panther', 'captain america', 'doctor strange', 'doctor strange', 'iron man', 'spider man']

# %% [markdown]
# 3. Create a list of all odd numbers between 1 and a max number. Max number is something you need to take from a user using input() function

# %%
max_number = int(input('Enter the maximum number:'))
odd_numbers = []
for i in range(1,max_number+1):
    if i%2 == 1:
        odd_numbers.append(i)
print(f'The odd numbers between 1 and {max_number} are: {odd_numbers}')
# Out:
# The odd numbers between 1 and 15 are: [1, 3, 5, 7, 9, 11, 13, 15]

# %%
max_number = int(input('Enter the maximum number:'))
odd_numbers = [i for i in range(1, max_number+1) if i%2 == 1]
print(odd_numbers)
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]
